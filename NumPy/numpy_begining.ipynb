# %%
import numpy as np
import time

# %%
size = 1_000_000

#Python list
py_list = list(range(size))
start = time.time()
sq_list = [x**2 for x in py_list]
end = time.time()
print(f"Python list time = {end - start} sec")

# numpy arrays
np_array = np.array(py_list)
start = time.time()

# vectorization
sq_array = np_array ** 2

end = time.time()
print(f"Numpy array time = {end - start} sec")


print(arr, type(arr))
# Out:
# Python list time = 2.303264856338501 sec
# Numpy array time = 0.10138773918151855 sec
# [1 2 3 4 5] <class 'numpy.ndarray'>

# %%
#memory
import sys

print(f"Python list size = {sys.getsizeof(py_list) * len(py_list)} bytes")
print(f"Numpy array size = {np_array.nbytes} bytes")
# Out:
# Python list size = 8000056000000 bytes
# Numpy array size = 8000000 bytes
