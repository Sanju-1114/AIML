# %%
import numpy as np

#Data Types
# arr = np.array([1, 2, 3, 4, 5])
# arr = np.array([1, 2, 3, 4, 5.32])
# arr = np.array([1, 2, 3, 4, 5.32, "prime"])
arr1 = np.array([3 + 5j])
arr2 = np.array([2 + 3j])
print(arr1 - arr2)
# Out:
# [1.+2.j]
