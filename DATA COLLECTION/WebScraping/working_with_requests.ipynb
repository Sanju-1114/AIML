# %%
import requests

URL = "https://www.scrapethissite.com/pages/simple/"
res = requests.get(URL)

# %%
print(res.status_code)
# Out:
# 200

# %%
# if(res.status_code == 200):
#     print(res.text)

# if(res.status_code == 200):
#     print(res.content)

if(res.status_code == 200):
    print(res.headers)
# Out:
# {'Date': 'Sun, 15 Mar 2026 10:53:01 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Nel': '{"report_to":"heroku-nel","response_headers":["Via"],"max_age":3600,"success_fraction":0.01,"failure_fraction":0.1}', 'Report-To': '{"group":"heroku-nel","endpoints":[{"url":"https://nel.heroku.com/reports?s=OMTWvs6ttYmqwMPi%2FoNUhistqqyOCjLS9XUmtlcUEKY%3D\\u0026sid=67ff5de4-ad2b-4112-9289-cf96be89efed\\u0026ts=1773571981"}],"max_age":3600}', 'Reporting-Endpoints': 'heroku-nel="https://nel.heroku.com/reports?s=OMTWvs6ttYmqwMPi%2FoNUhistqqyOCjLS9XUmtlcUEKY%3D&sid=67ff5de4-ad2b-4112-9289-cf96be89efed&ts=1773571981"', 'Server': 'cloudflare', 'Via': '1.1 heroku-router', 'cf-cache-status': 'DYNAMIC', 'Content-Encoding': 'zstd', 'CF-RAY': '9dcaf8d07f93fd41-SIN', 'alt-svc': 'h3=":443"; ma=86400'}

# %%
with open("scraped_data/data1.html", "w", encoding="utf-8") as f:
    f.write(res.text)
