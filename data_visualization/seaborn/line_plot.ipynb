# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme()

tips = sns.load_dataset("tips")

# %%
sns.lineplot(
    data=tips,
    x="total_bill",
    y="tip"
)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
flights = tips = sns.load_dataset("flights")

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
sns.set_theme(style="ticks")

sns.lineplot(
    data = flights,
    x="year",
    y="passengers"
)
# Out:
# <Axes: xlabel='year', ylabel='passengers'>
